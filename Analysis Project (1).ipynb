# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Loan_defualter.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
#### In this Dataset We have 14 columns And 10000 Records
    #This Dataset All Records are non null

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ## CLEANING DATA

# %%
df.drop(['RowNumber'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1015.8+ KB

# %% [markdown]
# ## FEATURES OF DATASET

# %%
df.describe()
# Out:
#          CustomerId   CreditScore           Age        Tenure        Balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count   10000.000000  10000.00000    10000.000000     10000.000000
# mean        1.530200      0.70550        0.515100    100090.239881
# std         0.581654      0.45584        0.499797     57510.492818
# ...

# %% [markdown]
# ## Analysis

# %% [markdown]
# ## Questions

# %% [markdown]
# ### 1.Find all record of the Surname each having CreditScore is more than 700 And Salary is more than 110000

# %%
A=df['Surname'].loc[(df['CreditScore']>700) & (df['EstimatedSalary']>110000)].value_counts()
A
# Out:
# Trevisano      7
# Martin         6
# Smith          6
# Wang           6
# Watson         6
#               ..
# Anenechukwu    1
# Nkemdirim      1
# Estrada        1
# Nolan          1
# Ch'in          1
# Name: Surname, Length: 940, dtype: int64

# %%
# Barplot

A.plot(kind='bar',color='red')

plt.title("CreditScore records less than 700 and Estimeted salary 110000",color="black")

plt.show()

# %% [markdown]
# ### 2.Find all records of Smith Surname person CustomerId and their CreditScore

# %%
df['CustomerId'].loc[(df['Surname']=='Smith') & (df['CreditScore'])].value_counts()
# Out:
# 15704769    1
# 15699598    1
# 15679770    1
# 15805104    1
# 15776850    1
# 15608873    1
# 15674720    1
# 15706268    1
# 15609987    1
# 15725002    1
# 15572706    1
# 15759690    1
# 15793311    1
# Name: CustomerId, dtype: int64

# %%
df['CustomerId'].loc[(df['Surname']=='Smith') & (df['CreditScore'])].value_counts().plot(kind="bar")
plt.xlabel("Coustmer Id")
plt.title("Smith Coustmer CreditScore",color="Blue")
plt.show()

# %% [markdown]
# ### 3.Find the records of Surname having EstimatedSalary is less than 120000 and CreditScore is less than 400

# %%
c=df['Exited'].loc[(df['EstimatedSalary']<120000) & (df['CreditScore']<400)].mean()
c
# Out:
# 1.0

# %% [markdown]
# ### 4.Find all records of Thomas Surname custmers and their CustomerId And Loan Tenure

# %%
df[['CustomerId','Tenure']].loc[df['Surname']=='Thomas']
# Out:
#       CustomerId  Tenure
# 1193    15779947       6
# 2340    15595728       0
# 2684    15631927       7
# 2785    15771417       7
# 7645    15698522       9
# 8877    15696371       1
# 9111    15711062       5
# 9765    15777067       2

# %% [markdown]
# ### 5.Find the records of Lin Surname,No of products & CreditScore details.

# %%
df[['CreditScore','NumOfProducts']].loc[df['Surname']=='Lin']
# Out:
#       CreditScore  NumOfProducts
# 578           593              1
# 942           376              1
# 1912          687              1
# 2104          768              3
# 2369          648              1
# 2943          678              1
# 5231          822              3
# 5267          584              2
# 5441          751              1
# 6371          602              2
# 7037          568              1
# 7350          669              2
# 7731          638              1
# 8566          679              1
# 8762          350              1
# 9128          693              1
# 9454          727              2
# 9830          593              1

# %% [markdown]
# ### 6.Find the record of Forbes Surname custmer Balance amout of loan and loan Tenure

# %%
df[['Balance','Tenure']].loc[df['Surname']=='Forbes']
# Out:
#         Balance  Tenure
# 510    67238.98      10
# 1790  108071.36       3
# 2256  163139.27       2
# 2368       0.00      10
# 3299       0.00       9
# 3852  127157.04       9
# 4174       0.00       4
# 4761  106045.92       3
# 5720   92783.68       6
# 5864       0.00       9
# 6253  106011.59       5
# 8434  122403.24       7
# 8791       0.00       9
# 9411   78119.59       4
# 9446   73218.89       4
# 9703  111094.05       7

# %% [markdown]
# ### 7.Find the records of each custmers have loan Balance is more than 200000 and loan tenure less than 10 years.

# %%
df[['Surname']].loc[(df['Balance']>200000) & (df['Tenure']<10)]
# Out:
#          Surname
# 138         Chia
# 520    Macartney
# 720      Fleming
# 1067       Dilke
# 1174  Despeissis
# 1365        Kang
# 1533       Moore
# 2092          Lo
# 2597    Chidubem
# 2709         Mao
# 3150  Olisaemeka
# 3280      To Rot
# 3588    McIntosh
# 3920     Thomson
# 4436   Golovanov
# 4533      Ch'ang
# 5254       Ts'ui
# 5871       Burke
# 6271      Stokes
# 6497      Bancks
# 6717        Shaw
# 6913          Ku
# 7353   Macdonald
# 7632     Sinnett
# 7887       Conti
# 8027    Atkinson
# 8063      Connor
# 8702     Udinesi
# 8733      Haddon
# 8794        Webb
# 8982      Coates
# 9833       McKay
# 9920       Smith

# %% [markdown]
# ### 8.Find the estimeted Salary and CreditScore of Mr.Loggia

# %%
df[['EstimatedSalary','CreditScore']].loc[df['Surname']=='Loggia'].mean()
# Out:
# EstimatedSalary    93952.890000
# CreditScore          608.166667
# dtype: float64

# %%
df[['EstimatedSalary','CreditScore']].loc[df['Surname']=='Loggia'].mean().plot(kind='pie',autopct='%1.0f%%',explode=(0,0.3))

plt.title("Estimeted Salary And Creditscore Of Loggia Surname Coustmers")
plt.show()

# %% [markdown]
# ### 9.Find the Records of McKay surname IsActive members and their creditscore and Exited from Loan

# %%
df[['Exited','CreditScore','IsActiveMember']].loc[df['Surname']=='McKay']
# Out:
#       Exited  CreditScore  IsActiveMember
# 581        1          607               1
# 1040       0          580               1
# 1799       0          850               1
# 1972       0          733               0
# 2799       0          760               0
# 2882       0          551               1
# 4038       1          469               0
# 4339       0          559               1
# 4609       0          581               1
# 4631       0          659               0
# 4657       0          687               1
# 6731       0          503               1
# 7110       0          679               1
# 7287       0          644               1
# 8404       0          586               1
# 8665       0          821               0
# 9062       1          720               0
# 9612       0          776               0
# 9833       0          699               0

# %% [markdown]
# ### 10.Find the records of surname they exited  from loan more than 3 and their tenure 10

# %%
df[['Surname']].loc[(df['Exited']<3) & (df['Tenure']==10)]
# Out:
#          Surname
# 12           Kay
# 50    Chidiebele
# 67       Chibugo
# 79        Postle
# 85       Ndukaku
# ...          ...
# 9934        West
# 9945    Cattaneo
# 9950     Salinas
# 9956       Nucci
# 9996   Johnstone
#
# [490 rows x 1 columns]

# %%
sns.pairplot(df)

# %%
corr=df.corr()

# %%
corr
# Out:
#                  CustomerId  CreditScore       Age    Tenure   Balance  \
# CustomerId         1.000000     0.005308  0.009497 -0.014883 -0.012419
# CreditScore        0.005308     1.000000 -0.003965  0.000842  0.006268
# Age                0.009497    -0.003965  1.000000 -0.009997  0.028308
# Tenure            -0.014883     0.000842 -0.009997  1.000000 -0.012254
# Balance           -0.012419     0.006268  0.028308 -0.012254  1.000000
# NumOfProducts      0.016972     0.012238 -0.030680  0.013444 -0.304180
# HasCrCard         -0.014025    -0.005458 -0.011721  0.022583 -0.014858
# IsActiveMember     0.001665     0.025651  0.085472 -0.028362 -0.010084
# EstimatedSalary    0.015271    -0.001384 -0.007201  0.007784  0.012797
# Exited            -0.006248    -0.027094  0.285323 -0.014001  0.118533
#
#                  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# CustomerId            0.016972  -0.014025        0.001665         0.015271
# ...

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(corr,annot=True,cmap="viridis")
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df,y="Age",x="EstimatedSalary")
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Age'>

# %%
sns.scatterplot(data=df,y="Age",x="EstimatedSalary",hue="Balance")
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Age'>

# %%
df["Age"].value_counts()
# Out:
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
#      ...
# 92      2
# 82      1
# 88      1
# 85      1
# 83      1
# Name: Age, Length: 70, dtype: int64

# %%
df["Age"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(data=df,y="Age",x="IsActiveMember")
# Out:
# <Axes: xlabel='IsActiveMember', ylabel='Age'>
